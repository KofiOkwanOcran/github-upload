# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import pearsonr

# %%
data = pd.read_csv('hf_data.csv')
data.head(5)
# Out:
#     Region          District             FacilityName           Type  \
# 0  Ashanti     Offinso North        A.M.E Zion Clinic         Clinic
# 1  Ashanti  Bekwai Municipal        Abenkyiman Clinic         Clinic
# 2  Ashanti      Adansi North     Aboabo Health Centre  Health Centre
# 3  Ashanti     Afigya-Kwabre  Aboabogya Health Centre  Health Centre
# 4  Ashanti            Kwabre     Aboaso Health Centre  Health Centre
#
#            Town   Ownership  Latitude  Longitude
# 0      Afrancho        CHAG   7.40801   -1.96317
# 1  Anwiankwanta     Private   6.46312   -1.58592
# 2   Aboabo No 2  Government   6.22393   -1.34982
# 3     Aboabogya  Government   6.84177   -1.61098
# 4        Aboaso  Government   6.84177   -1.61098

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3756 entries, 0 to 3755
# Data columns (total 8 columns):
# Region          3756 non-null object
# District        3756 non-null object
# FacilityName    3756 non-null object
# Type            3756 non-null object
# Town            3603 non-null object
# Ownership       3756 non-null object
# Latitude        3732 non-null float64
# Longitude       3732 non-null float64
# dtypes: float64(2), object(6)
# memory usage: 234.9+ KB

# %%
data.isnull().sum()
# Out:
# Region            0
# District          0
# FacilityName      0
# Type              0
# Town            153
# Ownership         0
# Latitude         24
# Longitude        24
# dtype: int64

# %%
data.describe()
# Out:
#           Latitude    Longitude
# count  3732.000000  3732.000000
# mean      6.955678    -1.074580
# std       1.679332     1.021352
# min       4.796180    -3.235880
# 25%       5.687642    -1.809792
# 50%       6.468705    -1.058117
# 75%       7.430555    -0.215870
# max      11.146670     1.191440

# %%
data[pd.isnull(data.Town)].tail(50)
# Out:
#        Region                 District  \
# 3615  Western               Wassa West
# 3616  Western               Wassa West
# 3618  Western               Wassa West
# 3619  Western             Aowin Suaman
# 3620  Western             Aowin Suaman
# 3621  Western             Aowin Suaman
# 3622  Western             Aowin Suaman
# 3623  Western             Aowin Suaman
# 3624  Western  Bibiani-Anhwiaso-Bekwai
# 3626  Western  Bibiani-Anhwiaso-Bekwai
# 3627  Western  Bibiani-Anhwiaso-Bekwai
# 3628  Western         Sefwi-Akontombra
# 3629  Western         Sefwi-Akontombra
# 3630  Western             Sefwi Wiawso
# 3631  Western             Sefwi Wiawso
# 3633  Western             Sefwi Wiawso
# 3634  Western             Sefwi Wiawso
# 3635  Western             Sefwi Wiawso
# 3636  Western             Sefwi Wiawso
# 3637  Western               Nzema East
# 3638  Western               Nzema East
# 3639  Western               Nzema East
# 3640  Western               Nzema East
# 3641  Western               Nzema East
# 3643  Western                   Jomoro
# 3644  Western                   Jomoro
# 3657  Western  Bibiani-Anhwiaso-Bekwai
# 3660  Western  Bibiani-Anhwiaso-Bekwai
# 3661  Western  Bibiani-Anhwiaso-Bekwai
# 3662  Western  Bibiani-Anhwiaso-Bekwai
# 3664  Western                Ellembele
# 3665  Western                Ellembele
# 3666  Western                Ellembele
# 3667  Western                Ellembele
# 3670  Western                Ellembele
# 3676  Western                Ellembele
# 3677  Western                Ellembele
# 3678  Western                Ellembele
# 3682  Western                   Jomoro
# 3688  Western                  Juabeso
# 3691  Western                  Juabeso
# 3722  Western             Sefwi Wiawso
# 3723  Western                    Shama
# 3724  Western                    Shama
# 3725  Western                    Shama
# 3726  Western  Tarkwa Nsuaem Municipal
# 3727  Western  Tarkwa Nsuaem Municipal
# 3728  Western  Tarkwa Nsuaem Municipal
# 3730  Western        Wassa-Amenfi West
# 3735  Western        Wassa-Amenfi West
#
#                                            FacilityName  \
# 3615                                      Teysec Clinic
# 3616                                       Daamang CHPS
# 3618                G.A.G/A.G.A/A.A.I.L/Sam Jona Clinic
# 3619                                          Jema CHPS
# 3620                              Dadieso Health Centre
# 3621                                Kwasuo/Bantama CHPS
# 3622                                         SDA Clinic
# 3623                               Amonie Presby Clinic
# 3624                                      Wenchi Clinic
# 3626                               Bekwai Health Centre
# 3627                                   Red Black Clinic
# 3628                           Akontombra Health Centre
# 3629                                         Yamfo CHPS
# 3630                              Abrabra Health Centre
# 3631                            Ackaakrom Health Centre
# 3633                                   Aboagyekrom CHPS
# 3634                         Wiawso Government Hospital
# 3635                                       Paboase CHPS
# 3636                  Wiaso District Health Directorate
# 3637                                    Aidoosuazo CHPS
# 3638                                     Kwasikrom CHPS
# 3639                                    A.B Bokazo CHPS
# 3640                         Krisan Refugee Camp Clinic
# 3641                             Kutukrom Health Centre
# 3643                                    New Town Clinic
# 3644                                      Fatima Clinic
# 3657                      Central African Gold Hospital
# 3660                               Divine Love Hospital
# 3661                                        ISOS Clinic
# 3662  Bibiani-Anhwiaso-Bekwai District Health Direct...
# 3664                               Nana Benie M. Clinic
# 3665                                A. B. Bokazo Clinic
# 3666                     St. Martin de Porres Hospitakl
# 3667                                 Krisan Camp Clinic
# 3670                                      Mobile Clinic
# 3676                                    NASS SCH Clinic
# 3677             West African Rescue Association Clinic
# 3678              Ellembele District Health Directorate
# 3682                                       Angel Clinic
# 3688                                    Nyame Ama Clinc
# 3691                                  Nallice Maternity
# 3722                                 Greenshield Clinic
# 3723                                   Living Well CHPS
# 3724                                      Inchaban CHPS
# 3725                                St.Benedit Hospital
# 3726                         Church of Pentecost Clinic
# 3727                                   Sam Jonna Clinic
# 3728                                      Divine Clinic
# 3730                                     Kwabeng Clinic
# 3735                                 Asanco SHS Sickbay
#
#                              Type Town         Ownership  Latitude  Longitude
# 3615                       Clinic  NaN           Private  5.434702  -2.144124
# 3616                         CHPS  NaN        Government  5.434702  -2.144124
# 3618                       Clinic  NaN           Private  5.434702  -2.144124
# 3619                         CHPS  NaN        Government  5.807107  -2.857711
# 3620                Health Centre  NaN        Government  5.807107  -2.857711
# 3621                         CHPS  NaN        Government  5.807107  -2.857711
# 3622                       Clinic  NaN              CHAG  5.807107  -2.857711
# 3623                       Clinic  NaN              CHAG  5.807107  -2.857711
# 3624                       Clinic  NaN              CHAG  6.275227  -2.263039
# 3626                Health Centre  NaN        Government  6.275227  -2.263039
# 3627                       Clinic  NaN           Private  6.275227  -2.263039
# 3628                Health Centre  NaN        Government  6.041831  -2.875169
# 3629                         CHPS  NaN        Government  6.041831  -2.875169
# 3630                Health Centre  NaN        Government  6.146702  -2.539603
# 3631                Health Centre  NaN        Government  6.146702  -2.539603
# 3633                         CHPS  NaN        Government  6.146702  -2.539603
# 3634                     Hospital  NaN        Government  6.146702  -2.539603
# 3635                         CHPS  NaN        Government  6.146702  -2.539603
# 3636  District Health Directorate  NaN        Government  6.146702  -2.539603
# 3637                         CHPS  NaN        Government  5.138789  -2.381362
# 3638                         CHPS  NaN        Government  5.138789  -2.381362
# 3639                         CHPS  NaN        Government  5.138789  -2.381362
# 3640                       Clinic  NaN  Quasi-Government  5.138789  -2.381362
# 3641                Health Centre  NaN        Government  5.138789  -2.381362
# 3643                       Clinic  NaN        Government  5.179371  -2.658640
# 3644                       Clinic  NaN              CHAG  5.179371  -2.658640
# 3657                     Hospital  NaN           Private  6.275227  -2.263039
# 3660                     Hospital  NaN        Government  6.275227  -2.263039
# 3661                       Clinic  NaN           Private  6.275227  -2.263039
# 3662  District Health Directorate  NaN        Government  6.275227  -2.263039
# 3664                       Clinic  NaN           Private       NaN        NaN
# 3665                       Clinic  NaN           Private       NaN        NaN
# 3666                     Hospital  NaN              CHAG       NaN        NaN
# 3667                       Clinic  NaN              CHAG       NaN        NaN
# 3670                       Clinic  NaN        Government       NaN        NaN
# 3676                       Clinic  NaN        Government       NaN        NaN
# 3677                       Clinic  NaN        Government       NaN        NaN
# 3678  District Health Directorate  NaN        Government       NaN        NaN
# 3682                       Clinic  NaN           Private  5.179371  -2.658640
# 3688                       Clinic  NaN              CHAG  5.179371  -2.658640
# 3691               Maternity Home  NaN           Private  5.179371  -2.658640
# 3722                       Clinic  NaN           Private  6.146702  -2.539603
# 3723                         CHPS  NaN        Government  5.019483  -1.626900
# 3724                         CHPS  NaN        Government  5.019483  -1.626900
# 3725                     Hospital  NaN           Private  5.019483  -1.626900
# 3726                       Clinic  NaN              CHAG  5.299986  -1.992202
# 3727                       Clinic  NaN           Private  5.299986  -1.992202
# 3728                       Clinic  NaN           Private  5.299986  -1.992202
# 3730                       Clinic  NaN           Private  5.653611  -2.165901
# 3735                       Clinic  NaN           Private  5.653611  -2.165901

# %%
data[pd.isnull(data.Latitude)]
# Out:
#         Region              District                            FacilityName  \
# 357    Ashanti          Bosome Freho                 Dunkura  Health  Centre
# 358    Ashanti          Bosome Freho                   Yapesa St.Mary Clinic
# 1651   Eastern             Akyemansa                         St Johns Clinic
# 2437  Northern               Gushegu                    Nabuli Health Centre
# 2438  Northern               Gushegu                         Damakung Clinic
# 2439  Northern               Gushegu                        Gushegu Hospital
# 3416   Western  Nzema East Municipal                              Ewuku CHPS
# 3417   Western  Nzema East Municipal                  Kutukrom Health Centre
# 3663   Western             Ellembele                  Aiyinase Health Centre
# 3664   Western             Ellembele                    Nana Benie M. Clinic
# 3665   Western             Ellembele                     A. B. Bokazo Clinic
# 3666   Western             Ellembele          St. Martin de Porres Hospitakl
# 3667   Western             Ellembele                      Krisan Camp Clinic
# 3668   Western             Ellembele                    Esiama Health Centre
# 3669   Western             Ellembele                          Kamgbunli CHPS
# 3670   Western             Ellembele                           Mobile Clinic
# 3671   Western             Ellembele                     Ampain Refugee Camp
# 3672   Western             Ellembele                         Aidoosuazo CHPS
# 3673   Western             Ellembele                          Kwasikrom CHPS
# 3674   Western             Ellembele                            Asomase CHPS
# 3675   Western             Ellembele                  Asasetre Health Centre
# 3676   Western             Ellembele                         NASS SCH Clinic
# 3677   Western             Ellembele  West African Rescue Association Clinic
# 3678   Western             Ellembele   Ellembele District Health Directorate
#
#                              Type        Town   Ownership  Latitude  Longitude
# 357                 Health Centre     Dunkura  Government       NaN        NaN
# 358                        Clinic      Yapesa        CHAG       NaN        NaN
# 1651                       Clinic      Ofoase        CHAG       NaN        NaN
# 2437                Health Centre      Nabuli  Government       NaN        NaN
# 2438                       Clinic   Damankung  Government       NaN        NaN
# 2439                     Hospital    Gushiegu  Government       NaN        NaN
# 3416                         CHPS       Ewuku  Government       NaN        NaN
# 3417                Health Centre    Kutukrom  Government       NaN        NaN
# 3663                Health Centre    Aiyinase  Government       NaN        NaN
# 3664                       Clinic         NaN     Private       NaN        NaN
# 3665                       Clinic         NaN     Private       NaN        NaN
# 3666                     Hospital         NaN        CHAG       NaN        NaN
# 3667                       Clinic         NaN        CHAG       NaN        NaN
# 3668                Health Centre      Esiama  Government       NaN        NaN
# 3669                         CHPS   Kamgbunli  Government       NaN        NaN
# 3670                       Clinic         NaN  Government       NaN        NaN
# 3671                       Clinic      Ampain  Government       NaN        NaN
# 3672                         CHPS  Aidoosuazo  Government       NaN        NaN
# 3673                         CHPS   Kwasikrom  Government       NaN        NaN
# 3674                         CHPS     Asomase  Government       NaN        NaN
# 3675                Health Centre    Asasetre  Government       NaN        NaN
# 3676                       Clinic         NaN  Government       NaN        NaN
# 3677                       Clinic         NaN  Government       NaN        NaN
# 3678  District Health Directorate         NaN  Government       NaN        NaN

# %%
data.fillna('None', inplace = True)

# %%
data.loc[(data['Town'] == 'None') & (data['Latitude'] == 'None')]
# Out:
#        Region   District                            FacilityName  \
# 3664  Western  Ellembele                    Nana Benie M. Clinic
# 3665  Western  Ellembele                     A. B. Bokazo Clinic
# 3666  Western  Ellembele          St. Martin de Porres Hospitakl
# 3667  Western  Ellembele                      Krisan Camp Clinic
# 3670  Western  Ellembele                           Mobile Clinic
# 3676  Western  Ellembele                         NASS SCH Clinic
# 3677  Western  Ellembele  West African Rescue Association Clinic
# 3678  Western  Ellembele   Ellembele District Health Directorate
#
#                              Type  Town   Ownership Latitude Longitude
# 3664                       Clinic  None     Private     None      None
# 3665                       Clinic  None     Private     None      None
# 3666                     Hospital  None        CHAG     None      None
# 3667                       Clinic  None        CHAG     None      None
# 3670                       Clinic  None  Government     None      None
# 3676                       Clinic  None  Government     None      None
# 3677                       Clinic  None  Government     None      None
# 3678  District Health Directorate  None  Government     None      None

# %%
len(data.Region.unique())
# Out:
# 10

# %%
len(data.District.unique())
# Out:
# 171

# %%
len(data.Type.unique())
# Out:
# 25

# %%
len(data.Town.unique())
# Out:
# 2447

# %%
len(data.Ownership.unique())
# Out:
# 12

# %%
new_data = data.drop([3664,3665, 3666, 3667, 3670, 3676, 3677, 3678], axis= 0)
new_data
# Out:
#        Region          District             FacilityName           Type  \
# 0     Ashanti     Offinso North        A.M.E Zion Clinic         Clinic
# 1     Ashanti  Bekwai Municipal        Abenkyiman Clinic         Clinic
# 2     Ashanti      Adansi North     Aboabo Health Centre  Health Centre
# 3     Ashanti     Afigya-Kwabre  Aboabogya Health Centre  Health Centre
# 4     Ashanti            Kwabre     Aboaso Health Centre  Health Centre
# ...       ...               ...                      ...            ...
# 3751  Western  Sefwi-Akontombra           Ackaakrom CHPS           CHPS
# 3752  Western  Sefwi-Akontombra             Apprutu CHPS           CHPS
# 3753  Western  Sefwi-Akontombra            Kojokrom CHPS           CHPS
# 3754  Western  Sefwi-Akontombra             Yawkrom CHPS           CHPS
# 3755  Western  Sefwi-Akontombra            Kofikrom CHPS           CHPS
#
#               Town   Ownership Latitude Longitude
# 0         Afrancho        CHAG  7.40801  -1.96317
# 1     Anwiankwanta     Private  6.46312  -1.58592
# 2      Aboabo No 2  Government  6.22393  -1.34982
# 3        Aboabogya  Government  6.84177  -1.61098
# 4           Aboaso  Government  6.84177  -1.61098
# ...            ...         ...      ...       ...
# 3751     Ackaakrom  Government  6.04183  -2.87517
# 3752       Apprutu  Government  6.04183  -2.87517
# 3753      Kojokrom  Government  6.04183  -2.87517
# 3754       Yawkrom  Government  6.04183  -2.87517
# 3755      Kofikrom  Government  6.04183  -2.87517
#
# [3748 rows x 8 columns]

# %%
new_data.groupby('Region').nunique().sort_values('FacilityName')
# Out:
#                Region  District  FacilityName  Type  Town  Ownership  \
# Region
# Upper West          1        10           160    12   134          4
# Upper East          1        10           227    14   180          4
# Northern            1        18           260    15   217          4
# Central             1        17           297    17   219          4
# Brong Ahafo         1        25           310    15   198          7
# Eastern             1        22           387    11   312          5
# Volta               1        15           394    13   294          5
# Western             1        20           464    12   313          6
# Greater Accra       1         7           484    14   235          6
# Ashanti             1        27           640    14   428          5
#
#                Latitude  Longitude
# Region
# Upper West          122        123
# Upper East          210        208
# Northern            211        217
# Central             194        194
# Brong Ahafo         250        250
# Eastern             336        338
# Volta               295        295
# Western             306        302
# Greater Accra       419        419
# Ashanti             513        511

# %%
'''START HERE'''

Central = new_data.loc[new_data['Region'] == 'Central']
Central.Town.value_counts(ascending = True).head(191)
# Out:
# Fomena            1
# Biriwa            1
# Jukwa             1
# Ahomakormbua      1
# Buduburam Camp    1
#                  ..
# Ewim              1
# Bronyi Krom       1
# Treposo           1
# Nkwatanan         1
# Nyanyano          2
# Name: Town, Length: 191, dtype: int64

# %%
'''IGNORE THIS'''

def ecdf(data):
    # Number of data points: n
    n = len(data)

    # x-data for the ECDF: x
    x = np.sort(data)

    # y-data for the ECDF: y
    y = np.arange(1, n+1) / n

    return x, y

# %%
plt.figure(figsize=(15,10))

x_values, y_values = ecdf(Central.Town)
# Plot the ECDF
_ = plt.plot(x_values, y_values, '.')
_ = plt.xlabel('Distinct towns')
_ = plt.xticks(rotation=40, fontsize = 5)
_ = plt.ylabel('ECDF')


# Overlay percentiles as red x's
percentiles = np.array([2.5, 25, 50, 75, 97.5])
ptiles_towns = np.percentile(range(len(Central.Town)), percentiles)
_ = plt.plot(ptiles_towns, percentiles/100, marker='D', color='red',
         linestyle='none')

# Show the plot
plt.show()

# %%
Central.Type.value_counts(ascending = False)
# Out:
# CHPS                               98
# Clinic                             65
# Health Centre                      54
# Maternity Home                     30
# District Health Directorate        12
# Hospital                           10
# RCH                                 9
# District Hospital                   8
# Training Institution                5
# Metropolitan Health Directorate     1
# Psychiatric Hospital                1
# Regional Health Directorate         1
# Metropolitan Hospital               1
# DHD                                 1
# Regional Hospital                   1
# Municipal  Health Directorate       1
# Polyclinic                          1
# Name: Type, dtype: int64

# %%
CHPS = Central.loc[(Central['Type'] == 'CHPS')]
Clinic = Central.loc[(Central['Type'] == 'Clinic')]
Health_centre = Central.loc[(Central['Type'] == 'Health Centre')]
Maternity_home = Central.loc[(Central['Type'] == 'Maternity_home')]
DHD = Central.loc[(Central['Type'] == 'District Health Directorate')]
Hospital = Central.loc[(Central['Type'] == 'Hospital')]
RCH = Central.loc[(Central['Type'] == 'RCH')]
District_hospital = Central.loc[(Central['Type'] == 'District Hospital')][:3]
b = pd.concat([CHPS, Clinic, Health_centre, Maternity_home, DHD, Hospital, RCH, District_hospital])

# %%
a = Central.Ownership.value_counts(ascending = False)
a
# Out:
# Government          226
# Private              55
# CHAG                 16
# Quasi-Government      2
# Name: Ownership, dtype: int64

# %%
plt.figure(figsize=(18,10))
plt.scatter(a, b)
plt.title('Contribution of Population Size to Infection Rate', fontsize=26)
plt.xlabel('Population Size', fontsize=22)
plt.xticks(fontsize = 16)
plt.ylabel('Total Cases', fontsize=22)
plt.yticks(fontsize = 16)
plt.grid()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-79-331ec582c489> in <module>
#       1 plt.figure(figsize=(18,10))
# ----> 2 plt.scatter(a, b)
#       3 plt.title('Contribution of Population Size to Infection Rate', fontsize=26)
#       4 plt.xlabel('Population Size', fontsize=22)
#       5 plt.xticks(fontsize = 16)
#
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\pyplot.py in scatter(x, y, s, c, marker, cmap, norm, vmin, vmax, alpha, linewidths, verts, edgecolors, plotnonfinite, data, **kwargs)
#    2845         verts=verts, edgecolors=edgecolors,
#    2846         plotnonfinite=plotnonfinite, **({"data": data} if data is not
# -> 2847         None else {}), **kwargs)
#    2848     sci(__ret)
#    2849     return __ret
#
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\__init__.py in inner(ax, data, *args, **kwargs)
#    1599     def inner(ax, *args, data=None, **kwargs):
#    1600         if data is None:
# -> 1601             return func(ax, *map(sanitize_sequence, args), **kwargs)
#    1602
#    1603         bound = new_sig.bind(ax, *args, **kwargs)
#
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\axes\_axes.py in scatter(self, x, y, s, c, marker, cmap, norm, vmin, vmax, alpha, linewidths, verts, edgecolors, plotnonfinite, **kwargs)
#    4432         # Process **kwargs to handle aliases, conflicts with explicit kwargs:
#    4433
# -> 4434         self._process_unit_info(xdata=x, ydata=y, kwargs=kwargs)
#    4435         x = self.convert_xunits(x)
#    4436         y = self.convert_yunits(y)
#
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\axes\_base.py in _process_unit_info(self, xdata, ydata, kwargs)
#    2124
#    2125         kwargs = _process_single_axis(xdata, self.xaxis, 'xunits', kwargs)
# -> 2126         kwargs = _process_single_axis(ydata, self.yaxis, 'yunits', kwargs)
#    2127         return kwargs
#    2128
#
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\axes\_base.py in _process_single_axis(data, axis, unit_name, kwargs)
#    2106                 # We only need to update if there is nothing set yet.
#    2107                 if not axis.have_units():
# -> 2108                     axis.update_units(data)
#    2109
#    2110             # Check for units in the kwargs, and if present update axis
#
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\axis.py in update_units(self, data)
#    1491         neednew = self.converter != converter
#    1492         self.converter = converter
# -> 1493         default = self.converter.default_units(data, self)
#    1494         if default is not None and self.units is None:
#    1495             self.set_units(default)
#
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\category.py in default_units(data, axis)
#     113         # default_units->axis_info->convert
#     114         if axis.units is None:
# --> 115             axis.set_units(UnitData(data))
#     116         else:
#     117             axis.units.update(data)
#
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\category.py in __init__(self, data)
#     179         self._counter = itertools.count()
#     180         if data is not None:
# --> 181             self.update(data)
#     182
#     183     @staticmethod
#
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\category.py in update(self, data)
#     213         # check if convertible to number:
#     214         convertible = True
# --> 215         for val in OrderedDict.fromkeys(data):
#     216             # OrderedDict just iterates over unique values in data.
#     217             if not isinstance(val, (str, bytes)):
#
# TypeError: unhashable type: 'numpy.ndarray'

# %%
corr, _ = pearsonr(b, a)
print('Pearsons correlation: %.3f' % corr)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-80-90e42bb31c4f> in <module>
# ----> 1 corr, _ = pearsonr(b, a)
#       2 print('Pearsons correlation: %.3f' % corr)
#
# C:\ProgramData\Anaconda3\lib\site-packages\scipy\stats\stats.py in pearsonr(x, y)
#    3387     n = len(x)
#    3388     if n != len(y):
# -> 3389         raise ValueError('x and y must have the same length.')
#    3390
#    3391     if n < 2:
#
# ValueError: x and y must have the same length.

# %%
Northern = new_data.loc[new_data['Region'] == 'Northern']
Northern.Town.value_counts(ascending = True)
# Out:
# Bamboi        1
# Bunjai        1
# Welensi       1
# Zogyele       1
# Gbulun        1
#              ..
# Bunkpurugu    3
# Sabonjida     4
# Savelugu      4
# Yendi         5
# Sawla         5
# Name: Town, Length: 217, dtype: int64

# %%
plt.figure(figsize=(15,10))

x_values, y_values = ecdf(Northern.Town)
# Plot the ECDF
_ = plt.plot(x_values, y_values, '.')
_ = plt.xlabel('Distinct towns')
_ = plt.xticks(rotation=40, fontsize = 5)
_ = plt.ylabel('ECDF')


# Overlay percentiles as red x's
percentiles = np.array([2.5, 25, 50, 75, 97.5])
ptiles_towns = np.percentile(range(len(Northern.Town)), percentiles)
_ = plt.plot(ptiles_towns, percentiles/100, marker='D', color='red',
         linestyle='none')

# Show the plot
plt.show()

# %%
Northern.Type.value_counts(ascending = False)
# Out:
# Health Centre                      108
# CHPS                                81
# District Health Directorate         17
# Clinic                              16
# District Hospital                   10
# Hospital                             8
# RCH                                  7
# Training Institution                 7
# Maternity Home                       6
# Polyclinic                           2
# Regional Hospital                    1
# Regional Health Directorate          1
# Metropolitan Health Directorate      1
# Others                               1
# Teaching Hospital                    1
# Name: Type, dtype: int64
