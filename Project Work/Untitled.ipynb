# %%
import pandas as pd

# %%
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
data = pd.read_csv(r'C:\Users\Kofi Okwan Ocran\Desktop\Azubi\Project Work\data.csv',index_col=0)

# %%
data
# Out:
#                             District                   FacilityName  \
# Region
# Ashanti                Offinso North              A.M.E Zion Clinic
# Ashanti             Bekwai Municipal              Abenkyiman Clinic
# Ashanti                 Adansi North           Aboabo Health Centre
# Ashanti                Afigya-Kwabre        Aboabogya Health Centre
# Ashanti                       Kwabre           Aboaso Health Centre
# Ashanti                Offinso North         Aboffour Health Centre
# Ashanti             Atwima-Nwabiagya         Abuakwa Maternity Home
# Ashanti              Atwima-Kwanwoma       Aburaso Methodist clinic
# Ashanti       Ejisu-Juaben Municipal          Achiase Health Centre
# Ashanti            Mampong Municipal          Adidwan Health Centre
# Ashanti                 Amansie West                  Adimposo CHPS
# Ashanti  Asante-Akim North Municipal                  Adom Hospital
# Ashanti              Ahafo-Ano South            Adom Maternity Home
# ...

# %%
data.describe()
# Out:
#           Latitude    Longitude
# count  3732.000000  3732.000000
# mean      6.955678    -1.074580
# std       1.679332     1.021352
# min       4.796180    -3.235880
# 25%       5.687642    -1.809792
# 50%       6.468705    -1.058117
# 75%       7.430555    -0.215870
# max      11.146670     1.191440
